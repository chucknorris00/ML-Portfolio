# %% [markdown]
# # Loading a Dataset in Pytorch

# %%
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import Dataset
import matplotlib.pyplot as plt

# %%
#download training data from open datasets.
training_data= datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)
#download test data from open datasets.
test_data= datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:15<00:00, 1.66MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 14.8MB/s]
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 4.88MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 4.56MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #download training data from open datasets.
# ----> 2 training_data= datasets.FashionMNIST(
#       3     root="data",
#       4     train=True,
#       5     download=True,
#       6     transform=ToTensor(),
#       7 )
#       8 #download test data from open datasets.
#       9 test_data= datasets.FashionMNIST(
#      10     root="data",
#      11     train=False,
#      12     download=True,
#      13     transform=ToTensor(),
#      14 )
#
# File c:\Users\santi\anaconda3\Lib\site-packages\torchvision\datasets\mnist.py:105, in MNIST.__init__(self, root, train, transform, target_transform, download)
#     102 if not self._check_exists():
#     103     raise RuntimeError("Dataset not found. You can use download=True to download it")
# --> 105 self.data, self.targets = self._load_data()
#
# File c:\Users\santi\anaconda3\Lib\site-packages\torchvision\datasets\mnist.py:127, in MNIST._load_data(self)
#     124 data = read_image_file(os.path.join(self.raw_folder, image_file))
#     126 label_file = f"{'train' if self.train else 't10k'}-labels-idx1-ubyte"
# --> 127 targets = read_label_file(os.path.join(self.raw_folder, label_file))
#     129 return data, targets
#
# File c:\Users\santi\anaconda3\Lib\site-packages\torchvision\datasets\mnist.py:551, in read_label_file(path)
#     549 if x.ndimension() != 1:
#     550     raise ValueError(f"x should have 1 dimension instead of {x.ndimension()}")
# --> 551 return x.long()
#
# KeyboardInterrupt:
